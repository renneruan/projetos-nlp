# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("Dmoz-Computers.csv")
df.head(5)
# Out:
#                   file_name  \
# 0  Intelligence_1434272.txt
# 1  Intelligence_1433615.txt
# 2  Intelligence_1434400.txt
# 3  Intelligence_1434281.txt
# 4  Intelligence_1434141.txt
#
#                                                 text       class
# 0  Principal Curves Page Introduction to principa...  Artificial
# 1  Iowa State University - Artificial Intelligenc...  Artificial
# 2  Paccanaro, Alberto Learning distributed repres...  Artificial
# 3  Attrasoft Provider of a number of neural netwo...  Artificial
# 4  LibML A machine learning library. New implemen...  Artificial

# %%
from find_best_hyperparameters import HyperparameterOptimizer

optmizer = HyperparameterOptimizer(df["text"], df["class"])
results = optmizer.get_results()
# Out:
# Tamanho de treino: (7600,)
# Tamanho de teste: (1900,)
# Encontrando melhores parâmetros para Naive Bayes Multinomial
#
# Lista de parâmetros utilizada: {'clf__alpha': [1e-05, 0.0001, 0.001, 0.1, 1, 10, 100, 1000], 'vect__max_df': (0.6, 0.8, 1.0), 'vect__min_df': (1, 3, 5, 10), 'vect__norm': ('l1', 'l2')}
#
# Fitting 2 folds for each of 192 candidates, totalling 384 fits
# Finalizada busca por melhores parâmetros para Naive Bayes Multinomial
# Encontrando melhores parâmetros para Regressão Logística
#
# Lista de parâmetros utilizada: {'clf__C': [0.001, 0.1, 1, 10, 100], 'clf__solver': ['lbfgs', 'liblinear', 'newton-cg'], 'vect__max_df': (0.6, 0.8, 1.0), 'vect__min_df': (1, 3, 5, 10), 'vect__norm': ('l1', 'l2')}
#
# Fitting 2 folds for each of 360 candidates, totalling 720 fits
# c:\Users\renne\anaconda3\envs\nlp_activities_dl\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# ...

# %%
nb_grid_df = pd.DataFrame(results["multi_nb"].cv_results_)
nb_grid_df.to_csv("nb_grid_results.csv")
nb_grid_df.head(5)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.203747      0.034304         0.137725        0.001921
# 1       0.238328      0.066557         0.131109        0.000196
# 2       0.226163      0.007171         0.248689        0.026841
# 3       0.206598      0.049458         0.123467        0.008928
# 4       0.163941      0.004483         0.118837        0.000947
#
#    param_clf__alpha  param_vect__max_df  param_vect__min_df param_vect__norm  \
# 0           0.00001                 0.6                   1               l1
# 1           0.00001                 0.6                   1               l2
# 2           0.00001                 0.6                   3               l1
# 3           0.00001                 0.6                   3               l2
# 4           0.00001                 0.6                   5               l1
#
#                                               params  split0_test_score  \
# ...

# %%
lr_grid_df = pd.DataFrame(results["logistic_regression"].cv_results_)
lr_grid_df.to_csv("lr_grid_results.csv")
lr_grid_df.head(5)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_clf__C  \
# 0       0.642602      0.083984         0.333450        0.052198         0.001
# 1       0.690685      0.007333         0.287170        0.016022         0.001
# 2       0.513258      0.026342         0.268693        0.009859         0.001
# 3       0.579038      0.169942         0.401333        0.067132         0.001
# 4       0.312962      0.022089         0.191383        0.002861         0.001
#
#   param_clf__solver  param_vect__max_df  param_vect__min_df param_vect__norm  \
# 0             lbfgs                 0.6                   1               l1
# 1             lbfgs                 0.6                   1               l2
# 2             lbfgs                 0.6                   3               l1
# 3             lbfgs                 0.6                   3               l2
# 4             lbfgs                 0.6                   5               l1
#
# ...

# %%
print(results["multi_nb"].best_score_)
print(results["multi_nb"].best_params_)

print(results["logistic_regression"].best_score_)
print(results["logistic_regression"].best_params_)
# Out:
# 0.6678947368421053
# {'clf__alpha': 0.1, 'vect__max_df': 0.6, 'vect__min_df': 1, 'vect__norm': 'l2'}
# 0.7023684210526315
# {'clf__C': 100, 'clf__solver': 'liblinear', 'vect__max_df': 0.6, 'vect__min_df': 1, 'vect__norm': 'l1'}

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df["text"], df["class"], test_size=0.2, random_state=42
)

print(f"Tamanho de treino: {X_train.shape}")
print(f"Tamanho de teste: {X_test.shape}")
# Out:
# Tamanho de treino: (7600,)
# Tamanho de teste: (1900,)

# %%
vectorizer_nb = TfidfVectorizer(max_df=0.8, min_df=3)

X_train_vectorized_nb = vectorizer_nb.fit_transform(test.X_train)
terms = vectorizer_nb.get_feature_names_out()
print(f"Quantia de features vetorizadas para texto de treino: {len(terms)}")

X_test_vectorized_nb = vectorizer_nb.transform(X_test)
# Out:
# Quantia de features vetorizadas para texto de treino: 4600

# %%
nb_clf = MultinomialNB(alpha=0.1)
nb_clf.fit(X_train_vectorized_nb, y_train)
# Out:
# MultinomialNB(alpha=0.1)

# %%
y_pred_nb = nb_clf.predict(X_test_vectorized_nb)
print(y_pred_nb)
# Out:
# ['CAD' 'Robotics' 'Graphics' ... 'Hardware' 'Graphics' 'Education']

# %%
print("Acurácia:", accuracy_score(y_test, y_pred_nb))
print("Relatório de classificação:\n", classification_report(y_test, y_pred_nb))
# Out:
# Acurácia: 0.69
# Relatório de classificação:
#                precision    recall  f1-score   support
#
#   Artificial       0.78      0.81      0.79       104
#          CAD       0.87      0.80      0.83       100
#    Companies       0.59      0.59      0.59       106
#     Computer       0.79      0.83      0.81        95
#  Consultants       0.57      0.78      0.66       100
#         Data       0.64      0.79      0.71       202
#    Education       0.89      0.90      0.89        96
#     Graphics       0.86      0.92      0.89       106
#     Hardware       0.72      0.61      0.66       104
#     Internet       0.78      0.61      0.68       108
#       Mobile       0.80      0.66      0.72       103
#   Multimedia       0.70      0.73      0.72       101
#         Open       0.60      0.57      0.58        95
#  Programming       0.52      0.52      0.52       104
#     Robotics       0.84      0.84      0.84       101
# ...

# %%
vectorizer_lr = TfidfVectorizer(max_df=0.8, min_df=1)

X_train_vectorized_lr = vectorizer_lr.fit_transform(test.X_train)
terms = vectorizer_lr.get_feature_names_out()
print(f"Quantia de features vetorizadas para texto de treino: {len(terms)}")

X_test_vectorized_lr = vectorizer_lr.transform(X_test)
# Out:
# Quantia de features vetorizadas para texto de treino: 16757

# %%
lr_clf = LogisticRegression(C=100, solver="liblinear")

lr_clf.fit(X_train_vectorized_lr, y_train)
# Out:
# LogisticRegression(C=100, solver='liblinear')

# %%
y_pred_lr = lr_clf.predict(X_test_vectorized_lr)
print(y_pred_lr)
# Out:
# ['CAD' 'Companies' 'Graphics' ... 'Hardware' 'Graphics' 'Consultants']

# %%
print("Acurácia:", accuracy_score(y_test, y_pred_lr))
print("Relatório de classificação:\n", classification_report(y_test, y_pred_lr))
# Out:
# Acurácia: 0.7205263157894737
# Relatório de classificação:
#                precision    recall  f1-score   support
#
#   Artificial       0.86      0.82      0.84       104
#          CAD       0.82      0.81      0.81       100
#    Companies       0.61      0.63      0.62       106
#     Computer       0.79      0.87      0.83        95
#  Consultants       0.61      0.76      0.68       100
#         Data       0.72      0.80      0.76       202
#    Education       0.88      0.89      0.88        96
#     Graphics       0.87      0.92      0.89       106
#     Hardware       0.65      0.59      0.62       104
#     Internet       0.70      0.66      0.68       108
#       Mobile       0.89      0.75      0.81       103
#   Multimedia       0.71      0.73      0.72       101
#         Open       0.66      0.68      0.67        95
#  Programming       0.53      0.50      0.51       104
#     Robotics       0.88      0.91      0.90       101
# ...
